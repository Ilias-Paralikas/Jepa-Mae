# %%
import sys

from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
from Data.CityScapes.datasets import CityscapesDataset

from MAE.patchifier import Patchifier

dataset = CityscapesDataset()


patchifier = Patchifier(patch_size=8, img_size=256)
x, _ =  dataset[0]
print(x.shape)

# %%
x, _ =  dataset[0]
print(x.shape)
# Out:
# torch.Size([3, 256, 256])

# %%
x, _ =  dataset[0]
x = patchifier.patchify(x.unsqueeze(0))
x =patchifier.unpatchify(x)
import matplotlib.pyplot as plt
plt.imshow(x[0].permute(1, 2, 0).numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9372549..1.0].
